# %% [markdown]
# <a href="https://colab.research.google.com/github/bvkcloud/30-Days-Of-JavaScript/blob/master/Kotlin_Android.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
/**
 * You can edit, run, and share this code.
 * play.kotlinlang.org
 */
fun main() {
    println("Hello, world!!!")
    println("Hello, world!!!")
    println("Hello, Brian!!!")
    println("Today is sunny!")
    println("1")
    println("2")
    println("3")
    println("I'm")
    println("learning")
    println("Kotlin!")
    println("Monday")
    println("Tuesday")
    println("Wednesday")
    println("Thursday")
    println("Friday")
    println("Tomorrow is rainy")
    println("There is a chance of snow")
    println("Cloudy")
}
